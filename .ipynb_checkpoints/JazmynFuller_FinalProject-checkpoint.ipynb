# %% [markdown]
# # CS381 Data Analytics Final Project

# %% [markdown]
# ### Due on 12/11/2019 23:59 pm

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %% [markdown]
# ### Dataset is based on an census income data
# https://archive.ics.uci.edu/ml/datasets/census+income

# %% [markdown]
# Data Set Information:
#
# Extraction was done by Barry Becker from the 1994 Census database.
#
#
# Attribute Information:
#
# Listing of attributes:
#
# * The last column >50K, <=50K is the target variable indicating whether the people earn less than or larger than 50K per year
#
# * age: continuous.
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# * sex: Female, Male.
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous.
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %% [markdown]
# ### However, I have modified the dataset and so you will need to load the dataset by reading a csv file I provided. In particular, I changed 50K to 80K just to reflect the inflation

# %%
df = pd.read_csv("adult_income2.csv")
df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %%
#ignore all rows with '?'
df = df[(df != '?').all(axis=1)]
df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 12      23           Private  122272     Bachelors             13
# ...

# %% [markdown]
# ### Your task is to build a model that can predict whether a people will earn <= 80K or > 80K

# %% [markdown]
# * Use any one of the models (Logistic, SVM, Decision Tree and Random Forecast) that we have covered in class.
# * Do not use any models that we have not covered in class.
# *
# * The best performance model will have an extra 5 points, but the whole project will still be capped at 20 points for the whole final project
# * The second and third performance model with have 2 extra points capped at 20 points for the whole final project.
#
#
#
#
# ### Make sure your work include the following steps

# %% [markdown]
# * EDA (chekcing missing values, removing outliers)
# * performed basic exploration of relationship, with plots and graphs
# * separated data set into training and testing
# * setup dummy variables to take care categorical variables
# * normalize numerical features if needed
# * tried at least two models and checked their model performance
# * performed cross-validations

# %% [markdown]
# First change the target variable salary to 0 and 1

# %%
df['salary'] = df['salary'].apply(lambda x: 0 if x == '<=80K' else 1)
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country  salary
# 0          2174             0              40  United-States       0
# ...

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32565   27       Private  257302  Assoc-acdm             12
# 32566   40       Private  154374     HS-grad              9
# 32567   58       Private  151910     HS-grad              9
# 32568   22       Private  201490     HS-grad              9
# 32569   52  Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 32565  Married-civ-spouse       Tech-support         Wife  White  Female
# 32566  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32567             Widowed       Adm-clerical    Unmarried  White  Female
# 32568       Never-married       Adm-clerical    Own-child  White    Male
# 32569  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country  salary
# 32565             0             0              38  United-States       0
# ...

# %%
sns.countplot(df['salary'])

# %% [markdown]
# ### Good Luck !!!

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Check for missing data

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
##double-checking to make sure there is no missing data values
df.isnull().any()
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %% [markdown]
# ## Remove Outliers

# %%
sns.boxplot(x=df['hours-per-week']);

# %%
print(df.shape)
df = df[df['hours-per-week']<175]
print(df.shape)
# Out:
# (30171, 15)
# (30168, 15)

# %%
sns.boxplot(x=df['capital-gain']);

# %%
print(df.shape)
df = df[df['capital-gain']<20000]
print(df.shape)
# Out:
# (30168, 15)
# (29936, 15)

# %%
sns.boxplot(x=df['capital-loss']);

# %%
print(df.shape)
df = df[df['capital-loss']<3000]
print(df.shape)
# Out:
# (29936, 15)
# (29928, 15)

# %%
df.groupby('salary').mean()
# Out:
#               age         fnlwgt  education-num  capital-gain  capital-loss  \
# salary
# 0       36.623041  190322.940831       9.630150    139.802005     52.432199
# 1       43.775031  188287.398572      11.562697   1769.568054    198.872820
#
#         hours-per-week
# salary
# 0            39.351040
# 1            45.623953

# %%
## Separate hours into 2 groups: Full time and part time
# df['hours-per-week'] = df['hours-per-week'].apply(lambda x: 0 if x == '<=29' else 1)
# df.head()

# %% [markdown]
# ### Inference Sex vs. Salary
# It looks like if you're a male, you have a higher probability of making more than 80k a year opposed to being a female.

# %%
g = sns.catplot(x="sex", hue="salary", data=df,
                height=7, kind="count", palette="colorblind")
g.set_xticklabels(rotation=90);
g.fig.suptitle('Sex vs. Salary');

# %% [markdown]
# ### Inference Occupation vs. Salary
# Here it having a mangerial or professional speciality position plays a significant role in obtaining a salary >= 80k, while the other occupations don't have a ratio as strong. Therefore, it's appears that having any of the other occupation, you're less likely to make above 80k.

# %%
g1 = sns.catplot(x="occupation", hue="salary", data=df,
                height=8, kind="count", palette="colorblind")
g1.set_xticklabels(rotation=90);
g1.fig.suptitle('Occupation vs. Salary');

# %% [markdown]
# ### Inference Education vs. Salary
# Individuals who completed college with a Bachelors and Masters have the strongest ratio out of all the other educational categories.

# %%
g2 = sns.catplot(x="education", hue="salary", data=df,
             height=9, kind="count", palette="colorblind")
g2.set_xticklabels(rotation=90);
g2.fig.suptitle('Education Level vs. Salary');

# %% [markdown]
# ### Inference Work Class vs. Salary
# Self-employed individuals and federal works have the strongest ratio here, so again, it's more likely they will be making 80k or more a year.

# %%
g3 = sns.catplot(x="workclass", hue="salary", data=df,
             height=9, kind="count", palette="colorblind")
g3.set_xticklabels(rotation=90);
g3.fig.suptitle('Work Class vs. Salary');

# %% [markdown]
# ### Inference Relationship & Relationship status vs. Salary
# The two charts below both show that if a person is married with this spouse present, the have a higher chance of earning 80k or more as a yearly salary. While the ratios for all other relationships/statuses are significantly lower.

# %%
g4 = sns.catplot(x="relationship", hue="salary", data=df,
             height=9, kind="count", palette="colorblind")
g4.set_xticklabels(rotation=90);
g4.fig.suptitle('Relationship vs. Salary');

# %%
g5 = sns.catplot(x="marital-status", hue="salary", data=df,
             height=9, kind="count", palette="colorblind")
g5.set_xticklabels(rotation=90);
g5.fig.suptitle('Marital Status vs. Salary');

# %%
#Create Dummies for WorkClass, sex, and education
work_class = pd.get_dummies(df['workclass'],drop_first=True)
marital = pd.get_dummies(df['marital-status'],drop_first=True)
sexes = pd.get_dummies(df['sex'],drop_first=True)
occup = pd.get_dummies(df['occupation'],drop_first=True)
educ = pd.get_dummies(df['education'],drop_first=True)
rela = pd.get_dummies(df['relationship'],drop_first=True)
sexes.head()
# Out:
#    Male
# 0     1
# 1     1
# 2     1
# 3     1
# 4     0

# %%
df2 = df[['salary','age','education-num','capital-gain','capital-loss','hours-per-week']]
df3 = pd.concat([df2,educ,sexes,work_class,occup,rela],axis=1)
df3.tail()
# Out:
#        salary  age  education-num  capital-gain  capital-loss  hours-per-week  \
# 32565       0   27             12             0             0              38
# 32566       1   40              9             0             0              40
# 32567       0   58              9             0             0              40
# 32568       0   22              9             0             0              20
# 32569       1   52              9         15024             0              40
#
#        11th  12th  1st-4th  5th-6th  ...  Prof-specialty  Protective-serv  \
# 32565     0     0        0        0  ...               0                0
# 32566     0     0        0        0  ...               0                0
# 32567     0     0        0        0  ...               0                0
# 32568     0     0        0        0  ...               0                0
# 32569     0     0        0        0  ...               0                0
#
# ...

# %%
df3.isnull().any()
# Out:
# salary               False
# age                  False
# education-num        False
# capital-gain         False
# capital-loss         False
# hours-per-week       False
# 11th                 False
# 12th                 False
# 1st-4th              False
# 5th-6th              False
# 7th-8th              False
# 9th                  False
# Assoc-acdm           False
# Assoc-voc            False
# Bachelors            False
# Doctorate            False
# HS-grad              False
# Masters              False
# Preschool            False
# Prof-school          False
# Some-college         False
# Male                 False
# Local-gov            False
# Private              False
# Self-emp-inc         False
# Self-emp-not-inc     False
# State-gov            False
# Without-pay          False
# Armed-Forces         False
# Craft-repair         False
# Exec-managerial      False
# Farming-fishing      False
# Handlers-cleaners    False
# Machine-op-inspct    False
# ...

# %% [markdown]
# ### Test_train_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df3.drop('salary',axis=1), 
                                                    df3['salary'], test_size=0.30, 
                                                    random_state=101)

model = LogisticRegression()
model.fit(X_train,Y_train)

predictions = model.predict(X_test)
print(classification_report(Y_test,predictions))
print('Accuracy Score: %s ' % round((accuracy_score(Y_test, predictions)),2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      6798
#            1       0.73      0.59      0.66      2181
#
#     accuracy                           0.85      8979
#    macro avg       0.80      0.76      0.78      8979
# weighted avg       0.84      0.85      0.84      8979
#
# Accuracy Score: 0.85

# %% [markdown]
# ### Support Vector Machine with rbf kernel

# %%
model = svm.SVC(kernel='rbf',C=5, gamma=.01)
model.fit(X_train,Y_train);
print(model)
# Needed for classification report
predictions = model.predict(X_test);
print(classification_report(Y_test,predictions))
print('Accuracy Score: %s ' % round((accuracy_score(Y_test, predictions)),2))
# Out:
# SVC(C=5, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92      6798
#            1       0.81      0.59      0.68      2181
#
#     accuracy                           0.87      8979
#    macro avg       0.84      0.77      0.80      8979
# weighted avg       0.86      0.87      0.86      8979
#
# Accuracy Score: 0.87

# %% [markdown]
# ### K-fold Cross Validation

# %%
### code here
import random
x = df3.drop(columns=["salary"])
y = df3["salary"]
score_vec = {}

X_train, X_test, y_train, y_test = train_test_split(df3.drop('salary',axis=1), df3['salary'], test_size=0.30, random_state= random.randint(1,10000))
for i in range(1,11):
    model = DecisionTreeClassifier(max_depth=10, criterion='gini')
    
    scores = cross_val_score(estimator=model, X=x, y=y, cv=10, n_jobs=5)
    score_vec[i] = round(scores.mean(),2)

# %%
score_vec
# Out:
# {1: 0.85,
#  2: 0.85,
#  3: 0.85,
#  4: 0.85,
#  5: 0.85,
#  6: 0.85,
#  7: 0.85,
#  8: 0.85,
#  9: 0.85,
#  10: 0.85}

# %% [markdown]
# ### Decision Trees

# %%
X = df3.drop('salary',axis=1)
Y = df3['salary']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

model = DecisionTreeClassifier(max_depth=10, criterion='gini')
model.fit(X_train,y_train);

# %%
predictions = model.predict(X_test)
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
print('Accuracy Score: %s'  % round(accuracy_score(y_test, predictions),2))
# Out:
# [[6359  520]
#  [ 813 1287]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91      6879
#            1       0.71      0.61      0.66      2100
#
#     accuracy                           0.85      8979
#    macro avg       0.80      0.77      0.78      8979
# weighted avg       0.85      0.85      0.85      8979
#
# Accuracy Score: 0.85

# %% [markdown]
# ### Random Forest

# %%
rfc = RandomForestClassifier(n_estimators=50)
rfc.fit(X_train, y_train)
rfc_pred = rfc.predict(X_test)
print(classification_report(y_test, rfc_pred))
print('Accuracy score: %s ' % round(accuracy_score(y_test, rfc_pred),2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90      6879
#            1       0.68      0.62      0.65      2100
#
#     accuracy                           0.84      8979
#    macro avg       0.78      0.76      0.77      8979
# weighted avg       0.84      0.84      0.84      8979
#
# Accuracy score: 0.84

# %% [markdown]
# #### The best performance model was the SVM with the kerenl='rbf', the C=5, and gamma= .01. The accuracy score was 87%.
