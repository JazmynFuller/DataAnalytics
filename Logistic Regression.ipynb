# %% [markdown]
# # Logistic Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
titanic_df = sns.load_dataset('titanic')
titanic_df.shape
# Out:
# (891, 15)

# %%
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Let's spilt the data between trainning (train_df) and testing dataset (test_df) first

# %%
train_df = titanic_df.sample(int(titanic_df.shape[0] * 0.8))
print(train_df.shape)
train_df.head()
# Out:
# (712, 15)
#      survived  pclass   sex   age  sibsp  parch   fare embarked   class  who  \
# 602         0       1  male   NaN      0      0  42.40        S   First  man
# 225         0       3  male  22.0      0      0   9.35        S   Third  man
# 734         0       2  male  23.0      0      0  13.00        S  Second  man
# 452         0       1  male  30.0      0      0  27.75        C   First  man
# 153         0       3  male  40.5      0      2  14.50        S   Third  man
#
#      adult_male deck  embark_town alive  alone
# 602        True  NaN  Southampton    no   True
# 225        True  NaN  Southampton    no   True
# 734        True  NaN  Southampton    no   True
# 452        True    C    Cherbourg    no   True
# 153        True  NaN  Southampton    no  False

# %% [markdown]
# Remember the row that are in the full df, but not in the training set

# %%
testing_rows = [idx for idx in titanic_df.index if idx not in train_df.index]
len(testing_rows)
# Out:
# 179

# %%
test_df = titanic_df.iloc[testing_rows, :]
print(test_df.shape)
test_df.head()
# Out:
# (179, 15)
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 11         1       1  female  58.0      0      0  26.5500        S  First
# 14         0       3  female  14.0      0      0   7.8542        S  Third
# 16         0       3    male   2.0      4      1  29.1250        Q  Third
# 18         0       3  female  31.0      1      0  18.0000        S  Third
# 23         1       1    male  28.0      0      0  35.5000        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 11  woman       False    C  Southampton   yes   True
# 14  child       False  NaN  Southampton    no   True
# 16  child       False  NaN   Queenstown    no  False
# 18  woman       False  NaN  Southampton    no  False
# 23    man        True    A  Southampton   yes   True

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # A new way for checking Missing Data

# %% [markdown]
# ## Using heatmap

# %%
sns.heatmap(train_df.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %% [markdown]
# So Age is missing about 20% which can be fixed by imputation. But deck seems too much

# %%
train_df.deck.unique()
# Out:
# [NaN, C, F, D, E, B, G, A]
# Categories (7, object): [C, F, D, E, B, G, A]

# %%
sns.set_style('whitegrid')
sns.countplot(x='survived',data= train_df, palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='survived',hue='pclass',data=train_df,palette='rainbow')

# %% [markdown]
# Now we want to fill in the missing value for Age. However, instead of just using the mean for all passengers, we fill it by the mean by pclass because wealthier passengers tend to be older

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='pclass',y='age',data=train_df,palette='winter')

# %%
def impute_age(cols):
    age = cols[0]
    pclass = cols[1]
    if pd.isnull(age):
        if pclass == 1:
            return 37
        elif pclass == 2:
            return 29
        else:
            return 24
    else:
        return age

# %% [markdown]
# Now apply this function

# %%
train_df['age'] = train_df[['age','pclass']].apply(impute_age,axis=1)

# %%
sns.heatmap(train_df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# Now deck has too much missin value and so we just drop that column. Also we will simply drop the row that has missing embarked

# %%
train_df.drop('deck',axis=1,inplace=True)

# %%
train_df.dropna(inplace=True)

# %%
train_df.shape
# Out:
# (710, 14)

# %%
train_df.head()
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked   class  who  \
# 602         0       1  male  37.0      0      0  42.40        S   First  man
# 225         0       3  male  22.0      0      0   9.35        S   Third  man
# 734         0       2  male  23.0      0      0  13.00        S  Second  man
# 452         0       1  male  30.0      0      0  27.75        C   First  man
# 153         0       3  male  40.5      0      2  14.50        S   Third  man
#
#      adult_male  embark_town alive  alone
# 602        True  Southampton    no   True
# 225        True  Southampton    no   True
# 734        True  Southampton    no   True
# 452        True    Cherbourg    no   True
# 153        True  Southampton    no  False

# %%
sns.heatmap(train_df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
# Now let's use just the numerical variables (will come back to revisit)

# %%
train = train_df[['survived','pclass', 'age', 'sibsp', 'parch', 'fare']]
train.head()
# Out:
#      survived  pclass   age  sibsp  parch   fare
# 602         0       1  37.0      0      0  42.40
# 225         0       3  22.0      0      0   9.35
# 734         0       2  23.0      0      0  13.00
# 452         0       1  30.0      0      0  27.75
# 153         0       3  40.5      0      2  14.50

# %% [markdown]
# # Building a Logistic Regression model

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(train.drop('survived',axis=1), 
                                                    train['survived'], test_size=0.20, 
                                                    random_state=101)
train.head()
# Out:
#      survived  pclass   age  sibsp  parch   fare
# 602         0       1  37.0      0      0  42.40
# 225         0       3  22.0      0      0   9.35
# 734         0       2  23.0      0      0  13.00
# 452         0       1  30.0      0      0  27.75
# 153         0       3  40.5      0      2  14.50

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = model.predict(X_test)

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
print(classification_report(y_test,predictions))
print(accuracy_score(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.89      0.79        87
#            1       0.72      0.46      0.57        56
#
#     accuracy                           0.72       143
#    macro avg       0.72      0.67      0.68       143
# weighted avg       0.72      0.72      0.70       143
#
# 0.7202797202797203

# %% [markdown]
# ## 70% on average, not bad!!

# %% [markdown]
# # NOW, let's talk about how to include the categorical variables (such as Sex, and Embarked etc)

# %%
sns.set_style('whitegrid')
sns.countplot(x='survived',hue='sex',data=train_df,palette='rainbow')

# %%
sns.set_style('whitegrid')
sns.countplot(x='survived',hue='embarked',data=train_df,palette='rainbow')

# %% [markdown]
# ## Clearly Sex and Embarked makes a difference

# %% [markdown]
# # Converting Categorical Features

# %%
sex = pd.get_dummies(train_df['sex'],drop_first=True)
embark = pd.get_dummies(train_df['embarked'],drop_first=True)

# %%
sex
# Out:
#      male
# 777     0
# 249     1
# 534     0
# 605     1
# 835     0
# 250     1
# 390     1
# 639     1
# 741     1
# 642     0
# 549     1
# 706     0
# 870     1
# 729     0
# 887     0
# 208     0
# 545     1
# 407     1
# 46      1
# 866     0
# 685     1
# 41      0
# 288     1
# 291     0
# 520     0
# 332     1
# 761     1
# 103     1
# 532     1
# 398     1
# ..    ...
# 9       0
# 794     1
# 457     0
# 252     1
# 624     1
# 369     0
# 638     0
# 276     0
# 374     0
# 548     1
# 44      0
# 475     1
# 129     1
# 335     1
# 678     0
# 858     0
# 634     0
# 744     1
# 169     1
# 373     1
# 517     1
# 623     1
# 198     0
# 599     1
# 801     0
# 651     0
# 492     1
# 72      1
# 807     0
# 113     0
#
# [711 rows x 1 columns]

# %%
embark
# Out:
#      Q  S
# 777  0  1
# 249  0  1
# 534  0  1
# 605  0  1
# 835  0  0
# 250  0  1
# 390  0  1
# 639  0  1
# 741  0  1
# 642  0  1
# 549  0  1
# 706  0  1
# 870  0  1
# 729  0  1
# 887  0  1
# 208  1  0
# 545  0  1
# 407  0  1
# 46   1  0
# 866  0  0
# 685  0  0
# 41   0  1
# 288  0  1
# 291  0  0
# 520  0  1
# 332  0  1
# 761  0  1
# 103  0  1
# 532  0  0
# 398  0  1
# ..  .. ..
# 9    0  0
# 794  0  1
# 457  0  1
# 252  0  1
# 624  0  1
# 369  0  0
# 638  0  1
# 276  0  1
# 374  0  1
# 548  0  1
# 44   1  0
# 475  0  1
# 129  0  1
# 335  0  1
# 678  0  1
# 858  0  0
# 634  0  1
# 744  0  1
# 169  0  1
# 373  0  0
# 517  1  0
# 623  0  1
# 198  1  0
# 599  0  0
# 801  0  1
# 651  0  1
# 492  0  1
# 72   0  1
# 807  0  1
# 113  0  1
#
# [711 rows x 2 columns]

# %%
train.head()
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 777         1       3   5.0      0      0  12.4750
# 249         0       2  54.0      1      0  26.0000
# 534         0       3  30.0      0      0   8.6625
# 605         0       3  36.0      1      0  15.5500
# 835         1       1  39.0      1      1  83.1583

# %%
train = pd.concat([train, sex, embark], axis=1)
train.head()
# Out:
#      survived  pclass   age  sibsp  parch     fare  male  Q  S
# 777         1       3   5.0      0      0  12.4750     0  0  1
# 249         0       2  54.0      1      0  26.0000     1  0  1
# 534         0       3  30.0      0      0   8.6625     0  0  1
# 605         0       3  36.0      1      0  15.5500     1  0  1
# 835         1       1  39.0      1      1  83.1583     0  0  0

# %% [markdown]
# ## So we have 3 more features (male, Q, S)

# %%
X_train, X_test, y_train, y_test = train_test_split(train.drop('survived',axis=1), 
                                                    train['survived'], test_size=0.30, 
                                                    random_state=101)
model = LogisticRegression()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(classification_report(y_test,predictions))
print(accuracy_score(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86       132
#            1       0.81      0.71      0.75        82
#
#     accuracy                           0.82       214
#    macro avg       0.82      0.80      0.81       214
# weighted avg       0.82      0.82      0.82       214
#
# 0.822429906542056

# %% [markdown]
# ## Wonderful, we have increased our F1-score from 70% to 81%

# %% [markdown]
# # Great Job
